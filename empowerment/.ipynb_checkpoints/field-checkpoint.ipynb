# %%
mfield = np.array(
        [['#', ' ', ' ', ' ', ' ', ' ', '#', '#', '#', ' ', ' ', ' ', ' ', ' ', '#'],
         ['#', ' ', '#', '#', '#', ' ', ' ', ' ', '#', '#', ' ', '#', ' ', '#', '#'],
         [' ', ' ', '#', ' ', ' ', ' ', '#', ' ', ' ', '#', ' ', '#', ' ', ' ', ' '],
         ['#', ' ', '#', ' ', '#', ' ', '#', '#', ' ', '#', ' ', '#', ' ', '#', ' '],
         ['#', ' ', '#', ' ', '#', ' ', '#', ' ', ' ', '#', ' ', '#', 'G', '#', ' '],
         ['#', ' ', '#', ' ', '#', ' ', '#', '#', 'P', ' ', ' ', '#', ' ', '#', ' '],
         ['#', ' ', ' ', ' ', '#', ' ', '#', ' ', ' ', '#', ' ', ' ', ' ', ' ', ' '],
         [' ', ' ', '#', ' ', ' ', ' ', '#', ' ', '#', '#', '#', '#', '#', ' ', '#'],
         ['#', ' ', '#', ' ', '#', ' ', '#', 'G', '#', ' ', ' ', ' ', '#', ' ', ' '],
         ['#', ' ', '#', ' ', '#', ' ', ' ', ' ', ' ', ' ', ' ', '#', '#', '#', ' '],
         ['#', ' ', ' ', ' ', '#', '#', ' ', '#', ' ', '#', ' ', ' ', ' ', '#', ' '],
         ['#', ' ', '#', '#', '#', ' ', ' ', '#', ' ', '#', ' ', '#', ' ', '#', '#'],
         [' ', ' ', '#', ' ', ' ', ' ', '#', '#', '#', '#', ' ', '#', ' ', '#', ' '],
         ['#', ' ', '#', '#', ' ', '#', '#', ' ', ' ', ' ', ' ', '#', ' ', ' ', ' '],
         ['#', '#', '#', ' ', ' ', ' ', '#', ' ', '#', '#', ' ', '#', 'G', '#', '#']])
